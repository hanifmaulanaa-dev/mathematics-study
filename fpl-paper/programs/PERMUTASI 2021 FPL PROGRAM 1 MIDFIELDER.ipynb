# %%
import numpy as np #untuk mengambil rumus2 seperti: cos, pi, linspace
import pandas as pd #salah satunya untuk membaca file
import matplotlib.pyplot as plt #untuk membuat grafik
from pandas import DataFrame, pivot_table
from numpy import argsort, array, zeros, fromstring, insert, delete

# %%
#membaca file dengan pandas sambil memisahkan time dan sample masing2 sebagai array

#DATA SUDAH DIURUTKAN BERDASARKAN POIN
KIPER = pd.read_excel("Databese FPL 2021-22 SORT.xls", sheet_name='Goalkeepers')
BEK = pd.read_excel("Databese FPL 2021-22 SORT.xls", sheet_name='Defenders')
TENGAH = pd.read_excel("Databese FPL 2021-22 SORT.xls", sheet_name='Midfielders')
DEPAN = pd.read_excel("Databese FPL 2021-22 SORT.xls", sheet_name='Forwards')
#sinyal2 = sinyal.to_numpy()
#time = np.array(sinyal[0:-1,0:1])
#array time berisi data yang dibaca dari file sinyal.xslx
#mulai kolom 2 sampai kolom 4002 pada baris ke-1(4000 data)
#time = time.astype(float) #dipilih tipe float
#sample = sinyal[0:-1,1:2]
#array sample berisi data yang dibaca dari file sinyal.xslx
#mulai kolom 2 sampai kolom 4002 pada baris ke-2(4000 data)
#sample = sample.astype(float) #dipilih tipe float

#DataFrame(KIPER)
#DataFrame(BEK)
#DataFrame(TENGAH)
#DataFrame(DEPAN)

# %%
KIPERAR = KIPER.to_numpy()
#print(KIPERAR)

#print(KIPERAR[0][1])

BEKAR = BEK.to_numpy()
#print(BEKAR)

TENGAHAR = TENGAH.to_numpy()
#print(TENGAHAR)

DEPANAR = DEPAN.to_numpy()
#print(DEPANAR)

# %% [markdown]
# ## PROGRAM KIPER

# %%
#print(KIPERAR)

#KIPERARRAT=array(zeros((2,50)))
KIPERARRAT=KIPERAR
#RATAAN POIN = TOTAL POIN MUSIM LALU / 38 (RATAAN PER PEMAIN)
for i in range (45): #ADA 46 KIPER
    KIPERARRAT[i][2]=KIPERAR[i][2]/38

#print(KIPERARRAT)
    
#KIPERARVAL=array(zeros((2,50)))
KIPERARVAL=KIPERARRAT
#VALUE = PELUANG POIN * RATAAN POIN
#BIKIN ARRAY BARU, ISINYA NAMA, TIM, COST, RATAAN POIN (CUMA NINDIHIN POINTS DI ARRAY LAMA)
for i in range (45): #ADA 46 KIPER 
    if KIPERARVAL[i][1]=='Arsenal' or KIPERARVAL[i][1]=='Chelsea' or KIPERARVAL[i][1]=='Liverpool':
        KIPERARVAL[i][2]=round(KIPERARRAT[i][2]*0.9,4)
    elif KIPERARVAL[i][1]=='Aston Villa' or KIPERARVAL[i][1]=='Man Utd':
        KIPERARVAL[i][2]=round(KIPERARRAT[i][2]*0.7,4)
    elif KIPERARVAL[i][1]=='Brighton' or KIPERARVAL[i][1]=='Burnley' or KIPERARVAL[i][1]=='Everton' or KIPERARVAL[i][1]=='Leicester' or KIPERARVAL[i][1]=='Man City' or KIPERARVAL[i][1]=='Newcastle' or KIPERARVAL[i][1]=='Southampton' or KIPERARVAL[i][1]=='Spurs' or KIPERARVAL[i][1]=='Wolves' or KIPERARVAL[i][1]=='West Ham':
        KIPERARVAL[i][2]=round(KIPERARRAT[i][2]*0.5,4)
    elif KIPERARVAL[i][1]=='Leeds' or KIPERARVAL[i][1]=='Watford':
        KIPERARVAL[i][2]=round(KIPERARRAT[i][2]*0.3,4)
    else:
        KIPERARVAL[i][2]=round(KIPERARRAT[i][2]*0.1,4)
        
#print(KIPERARVAL)

#URUTIN PEMAIN YG PUNYA VALUE TERTINGGI DI SETIAP POSISI
#DICARI VALUE MAX, DENGAN COST MIN
#COST <= 100

#ASCENDING SORT
KIPERARVALSORT=KIPERARVAL[argsort(KIPERARVAL[:, 2])]
print('Sorted Array : ')
print(KIPERARVALSORT)
# Out:
# Sorted Array :
# [['Gunn' 'Norwich' 0 4.0]
#  ['Raya' 'Brentford' 0.0 4.5]
#  ['Krul' 'Norwich' 0.0 4.5]
#  ['Bachmann' 'Watford' 0.0 4.5]
#  ['Steer' 'Aston Villa' 0.0 4.0]
#  ['Steele' 'Brighton' 0.0 4.0]
#  ['Hart' 'Spurs' 0.0 4.5]
#  ['Gunnarsson' 'Brentford' 0.0 4.0]
#  ['Ward' 'Leicester' 0.0 4.0]
#  ['McGovern' 'Norwich' 0.0 4.0]
#  ['Foster' 'Watford' 0.0 4.0]
#  ['Balcombe' 'Brentford' 0.0 4.0]
#  ['Söndergaard' 'Wolves' 0.0 4.0]
#  ['Butland' 'Crystal Palace' 0.0053 4.5]
#  ['Rúnarsson' 'Arsenal' 0.0237 4.0]
#  ['Virgínia' 'Everton' 0.0263 4.0]
#  ['Steffen' 'Man City' 0.0263 4.5]
#  ['Peacock-Farrell' 'Burnley' 0.0395 4.5]
#  ['Norris' 'Burnley' 0.0395 4.5]
#  ['Ruddy' 'Wolves' 0.0526 4.5]
#  ['Casilla' 'Leeds' 0.1105 4.5]
#  ['Randolph' 'West Ham' 0.1316 4.5]
#  ['Kelleher' 'Liverpool' 0.2368 4.5]
#  ['Adrián' 'Liverpool' 0.2605 4.5]
#  ['Guaita' 'Crystal Palace' 0.3263 4.5]
#  ['Forster' 'Southampton' 0.3947 4.5]
#  ['Ryan' 'Brighton' 0.4868 4.5]
# ...

# %% [markdown]
# ## PROGRAM DEFENDER

# %%
#print(BEKAR)

BEKARRAT=BEKAR
#RATAAN POIN = TOTAL POIN MUSIM LALU / 38 (RATAAN PER PEMAIN)
for i in range (162): #ADA 163 DEFENDER
    BEKARRAT[i][2]=BEKAR[i][2]/38

#print(BEKARRAT)
    
BEKARVAL=BEKARRAT
#VALUE = PELUANG POIN * RATAAN POIN
#BIKIN ARRAY BARU, ISINYA NAMA, TIM, COST, RATAAN POIN (CUMA NINDIHIN POINTS DI ARRAY LAMA)
for i in range (162): #ADA 163 DEFENDER  
    if BEKARVAL[i][1]=='Arsenal' or BEKARVAL[i][1]=='Chelsea' or BEKARVAL[i][1]=='Liverpool':
        BEKARVAL[i][2]=round(BEKARRAT[i][2]*0.9,4)
    elif BEKARVAL[i][1]=='Aston Villa' or BEKARVAL[i][1]=='Man Utd':
        BEKARVAL[i][2]=round(BEKARRAT[i][2]*0.7,4)
    elif BEKARVAL[i][1]=='Brighton' or BEKARVAL[i][1]=='Burnley' or BEKARVAL[i][1]=='Everton' or BEKARVAL[i][1]=='Leicester' or BEKARVAL[i][1]=='Man City' or BEKARVAL[i][1]=='Newcastle' or BEKARVAL[i][1]=='Southampton' or BEKARVAL[i][1]=='Spurs' or BEKARVAL[i][1]=='Wolves' or BEKARVAL[i][1]=='West Ham':
        BEKARVAL[i][2]=round(BEKARRAT[i][2]*0.5,4)
    elif BEKARVAL[i][1]=='Leeds' or BEKARVAL[i][1]=='Watford':
        BEKARVAL[i][2]=round(BEKARRAT[i][2]*0.3,4)
    else:
        BEKARVAL[i][2]=round(BEKARRAT[i][2]*0.1,4)
        
#print(BEKARVAL)

#ASCENDING SORT
BEKARVALSORT=BEKARVAL[argsort(BEKARVAL[:, 2])]
print('Sorted Array : ')
print(BEKARVALSORT)
# Out:
# Sorted Array :
# [['Pollock' 'Watford' 0 4.0]
#  ['Zimmermann' 'Norwich' 0.0 4.5]
#  ['Byram' 'Norwich' 0.0 4.5]
#  ['Hanley' 'Norwich' 0.0 4.5]
#  ['Ferguson' 'Crystal Palace' 0.0 4.5]
#  ['Jach' 'Crystal Palace' 0.0 4.5]
#  ['Pinnock' 'Brentford' 0.0 4.5]
#  ['Sørensen' 'Brentford' 0.0 4.5]
#  ['Roerslev' 'Brentford' 0.0 4.5]
#  ['Aarons' 'Norwich' 0.0 4.5]
#  ['Henry' 'Brentford' 0.0 4.5]
#  ['Guilbert' 'Aston Villa' 0.0 4.5]
#  ['Engels' 'Aston Villa' 0.0 4.5]
#  ['Saliba' 'Arsenal' 0.0 4.5]
#  ['Mavropanos' 'Arsenal' 0.0 4.5]
#  ['Kolasinac' 'Arsenal' 0.0 4.5]
#  ['Firpo' 'Leeds' 0.0 5.0]
#  ['Young' 'Aston Villa' 0.0 5.0]
#  ['Konaté' 'Liverpool' 0.0 5.5]
#  ['Jansson' 'Brentford' 0.0 4.5]
#  ['Sørensen' 'Norwich' 0.0 4.5]
#  ['Perraud' 'Southampton' 0.0 5.0]
#  ['Rose' 'Watford' 0.0 4.5]
#  ['Sessegnon' 'Spurs' 0.0 4.5]
#  ['Navarro' 'Watford' 0.0 4.0]
#  ['Omobamidele' 'Norwich' 0.0 4.0]
#  ['Davies' 'Liverpool' 0.0 4.0]
#  ['Goode' 'Brentford' 0.0 4.0]
# ...

# %% [markdown]
# ## PROGRAM MIDFIELDER

# %%
#print(TENGAHAR)

TENGAHARRAT=TENGAHAR
#RATAAN POIN = TOTAL POIN MUSIM LALU / 38 (RATAAN PER PEMAIN)
for i in range (195): #ADA 196 MIDFIELDER
    TENGAHARRAT[i][2]=TENGAHAR[i][2]/38

#print(TENGAHARRAT)
    
TENGAHARVAL=TENGAHARRAT
#VALUE = PELUANG POIN * RATAAN POIN
#BIKIN ARRAY BARU, ISINYA NAMA, TIM, COST, RATAAN POIN (CUMA NINDIHIN POINTS DI ARRAY LAMA)
for i in range (195): #ADA 196 MIDFIELDER  
    if TENGAHARVAL[i][1]=='Arsenal' or TENGAHARVAL[i][1]=='Chelsea' or TENGAHARVAL[i][1]=='Arsenal':
        TENGAHARVAL[i][2]=round(TENGAHARRAT[i][2]*0.9,4)
    elif TENGAHARVAL[i][1]=='Aston Villa' or  TENGAHARVAL[i][1]=='Man Utd':
        TENGAHARVAL[i][2]=round(TENGAHARRAT[i][2]*0.7,4)
    elif TENGAHARVAL[i][1]=='Brighton' or TENGAHARVAL[i][1]=='Burnley' or TENGAHARVAL[i][1]=='Everton' or TENGAHARVAL[i][1]=='Leicester' or TENGAHARVAL[i][1]=='Man City' or TENGAHARVAL[i][1]=='Newcastle' or TENGAHARVAL[i][1]=='Southampton' or TENGAHARVAL[i][1]=='Spurs' or TENGAHARVAL[i][1]=='Wolves' or TENGAHARVAL[i][1]=='West Ham':
        TENGAHARVAL[i][2]=round(TENGAHARRAT[i][2]*0.5,4)
    elif TENGAHARVAL[i][1]=='Leeds' or TENGAHARVAL[i][1]=='Watford':
        TENGAHARVAL[i][2]=round(TENGAHARRAT[i][2]*0.3,4)
    else:
        TENGAHARVAL[i][2]=round(TENGAHARRAT[i][2]*0.1,4)
        
#print(TENGAHARVAL)

#ASCENDING SORT
TENGAHARVALSORT=TENGAHARVAL[argsort(TENGAHARVAL[:, 2])]
print('Sorted Array : ')
print(TENGAHARVALSORT)
# Out:
# Sorted Array :
# [['Baah' 'Watford' 0 4.5]
#  ['Jensen' 'Brentford' 0.0 5.0]
#  ['Janelt' 'Brentford' 0.0 5.0]
#  ['Nørgaard' 'Brentford' 0.0 5.0]
#  ['Hourihane' 'Aston Villa' 0.0 5.0]
#  ['Rashica' 'Norwich' 0.0 5.5]
#  ['Louza' 'Watford' 0.0 5.5]
#  ['Zinckernagel' 'Watford' 0.0 5.5]
#  ['Sema' 'Watford' 0.0 5.5]
#  ['Cantwell' 'Norwich' 0.0 5.5]
#  ['Mbeumo' 'Brentford' 0.0 5.5]
#  ['Ghoddos' 'Brentford' 0.0 5.5]
#  ['Dasilva' 'Brentford' 0.0 5.5]
#  ['Canós' 'Brentford' 0.0 5.5]
#  ['Fosu' 'Brentford' 0.0 5.5]
#  ['Mwepu' 'Brighton' 0.0 6.0]
#  ['Trincão' 'Wolves' 0.0 6.0]
#  ['Sarr' 'Watford' 0.0 6.0]
#  ['Hungbo' 'Watford' 0.0 4.5]
#  ['Buendía' 'Aston Villa' 0.0 6.5]
#  ['Stiepermann' 'Norwich' 0.0 5.0]
#  ['McLean' 'Norwich' 0.0 5.0]
#  ['Dowell' 'Norwich' 0.0 5.5]
#  ['Guendouzi' 'Arsenal' 0.0 4.5]
#  ['Rupp' 'Norwich' 0.0 4.5]
#  ['Bidstrup' 'Brentford' 0.0 4.5]
#  ['Zamburek' 'Brentford' 0.0 4.5]
#  ['Dele-Bashiru' 'Watford' 0.0 4.5]
#  ['Torreira' 'Arsenal' 0.0 4.5]
# ...

# %% [markdown]
# ## PROGRAM FORWARD

# %%
#print(DEPANAR)

DEPANARRAT=DEPANAR
#RATAAN POIN = TOTAL POIN MUSIM LALU / 38 (RATAAN PER PEMAIN)
for i in range (57): #ADA 58 FORWARD
    DEPANARRAT[i][2]=DEPANAR[i][2]/38

#print(DEPANARRAT)
    
DEPANARVAL=DEPANARRAT
#VALUE = PELUANG POIN * RATAAN POIN
#BIKIN ARRAY BARU, ISINYA NAMA, TIM, COST, RATAAN POIN (CUMA NINDIHIN POINTS DI ARRAY LAMA)
for i in range (57): #ADA 58 FORWARD
    if DEPANARVAL[i][1]=='Arsenal' or DEPANARVAL[i][1]=='Chelsea' or DEPANARVAL[i][1]=='Liverpool':
        DEPANARVAL[i][2]=round(DEPANARRAT[i][2]*0.9,4)
    elif DEPANARVAL[i][1]=='Aston Villa' or DEPANARVAL[i][1]=='Man Utd':
        DEPANARVAL[i][2]=round(DEPANARRAT[i][2]*0.7,4)
    elif DEPANARVAL[i][1]=='Brighton' or DEPANARVAL[i][1]=='Burnley' or DEPANARVAL[i][1]=='Everton' or DEPANARVAL[i][1]=='Leicester' or DEPANARVAL[i][1]=='Man City' or DEPANARVAL[i][1]=='Newcastle' or DEPANARVAL[i][1]=='Southampton' or DEPANARVAL[i][1]=='Spurs' or DEPANARVAL[i][1]=='Wolves' or DEPANARVAL[i][1]=='West Ham':
        DEPANARVAL[i][2]=round(DEPANARRAT[i][2]*0.5,4)
    elif DEPANARVAL[i][1]=='Leeds' or DEPANARVAL[i][1]=='Watford':
        DEPANARVAL[i][2]=round(DEPANARRAT[i][2]*0.3,4)
    else:
        DEPANARVAL[i][2]=round(DEPANARRAT[i][2]*0.1,4)
        
#print(DEPANARVAL)

#ASCENDING SORT
DEPANARVALSORT=DEPANARVAL[argsort(DEPANARVAL[:, 2])]
print('Sorted Array : ')
print(DEPANARVALSORT)
# Out:
# Sorted Array :
# [['Perica' 'Watford' 0 4.5]
#  ['Daka' 'Leicester' 0.0 7.5]
#  ['Toney' 'Brentford' 0.0 6.5]
#  ['Pukki' 'Norwich' 0.0 6.0]
#  ['Samatta' 'Aston Villa' 0.0 5.5]
#  ['Forss' 'Brentford' 0.0 5.5]
#  ['Dervişoğlu' 'Brentford' 0.0 5.5]
#  ['Dennis' 'Watford' 0.0 5.0]
#  ['Deeney' 'Watford' 0.0 5.5]
#  ['Gray' 'Watford' 0.0 5.5]
#  ['João Pedro' 'Watford' 0.0 5.5]
#  ['Idah' 'Norwich' 0.0 5.0]
#  ['Success' 'Watford' 0.0 5.0]
#  ['Fletcher' 'Watford' 0.0 5.0]
#  ['Hugill' 'Norwich' 0.0 5.5]
#  ['Mateta' 'Crystal Palace' 0.0395 5.5]
#  ['Obafemi' 'Southampton' 0.0526 4.5]
#  ['Wesley' 'Aston Villa' 0.0553 5.5]
#  ['Nlundulu' 'Southampton' 0.1711 4.5]
#  ['Ayew' 'Crystal Palace' 0.1842 6.0]
#  ['Origi' 'Liverpool' 0.2368 5.0]
#  ['Benteke' 'Crystal Palace' 0.2789 6.5]
#  ['Gayle' 'Newcastle' 0.4079 5.5]
#  ['Davis' 'Aston Villa' 0.4237 4.5]
#  ['Connolly' 'Brighton' 0.5 5.5]
#  ['Jiménez' 'Wolves' 0.5658 7.5]
#  ['Barnes' 'Burnley' 0.6842 5.5]
# ...

# %%
#FORMASI YG DIPAKE UMUM (4-4-2)
#TENTUKAN COST UTK PEMAIN CADANGAN (DIPILIH 17, BERDASARKAN COST TERENDAH TIAP POSISI)
MAXCAD=17

# %%
#PROGRAM DINAMIK UNTUK FORWARD
DINAMIKDEPAN=[]

for i in range (58):
    for j in range (58):
        if j==i:
            break
        else:
            TDEPANVALUE=round(DEPANARVALSORT[i][2]+DEPANARVALSORT[j][2],4)
            TDEPANCOST=round(DEPANARVALSORT[i][3]+DEPANARVALSORT[j][3],4)
            #print([DEPANARVALSORT[i][0], DEPANARVALSORT[i][1], DEPANARVALSORT[j][0], DEPANARVALSORT[j][1], TDEPANVALUE, TDEPANCOST])
            DINAMIKDEPAN.append([DEPANARVALSORT[i][0], DEPANARVALSORT[i][1], DEPANARVALSORT[j][0], DEPANARVALSORT[j][1], TDEPANVALUE, TDEPANCOST])
        
#print(DINAMIKDEPAN)
#[Nama, Klub, Nama, Klub, Value, Cost]

DINAMIKDEPANAR = np.array(DINAMIKDEPAN)
print(DINAMIKDEPANAR)

#ASCENDING SORT
DINAMIKDEPANARSORT=DINAMIKDEPANAR[argsort(DINAMIKDEPANAR[:, 4])]
print('Sorted Array : ')
print(DINAMIKDEPANARSORT)
# Out:
# [['Daka' 'Leicester' 'Perica' 'Watford' '0.0' '12.0']
#  ['Toney' 'Brentford' 'Perica' 'Watford' '0.0' '11.0']
#  ['Toney' 'Brentford' 'Daka' 'Leicester' '0.0' '14.0']
#  ...
#  ['Firmino' 'Liverpool' 'Watkins' 'Aston Villa' '6.4342' '16.5']
#  ['Firmino' 'Liverpool' 'Aubameyang' 'Arsenal' '6.4421' '19.0']
#  ['Firmino' 'Liverpool' 'Kane' 'Spurs' '6.5237' '21.5']]
# Sorted Array :
# [['Daka' 'Leicester' 'Perica' 'Watford' '0.0' '12.0']
#  ['Success' 'Watford' 'João Pedro' 'Watford' '0.0' '10.5']
#  ['Success' 'Watford' 'Gray' 'Watford' '0.0' '10.5']
#  ...
#  ['Firmino' 'Liverpool' 'Watkins' 'Aston Villa' '6.4342' '16.5']
#  ['Firmino' 'Liverpool' 'Aubameyang' 'Arsenal' '6.4421' '19.0']
#  ['Firmino' 'Liverpool' 'Kane' 'Spurs' '6.5237' '21.5']]

# %%
#PROGRAM DINAMIK UNTUK MIDFIELDER
DINAMIKTENGAH=[]

for i in range (196):
    for j in range (196):
        for k in range (196):
            for l in range (196):
                if j==i or k==j or k==i or l==k or l==j or l==i:
                    break
                else:
                    TTENGAHVALUE=round(TENGAHARVALSORT[i][2]+TENGAHARVALSORT[j][2]+TENGAHARVALSORT[k][2]+TENGAHARVALSORT[l][2],4)
                    TTENGAHCOST=round(TENGAHARVALSORT[i][3]+TENGAHARVALSORT[j][3]+TENGAHARVALSORT[k][3]+TENGAHARVALSORT[l][3],4)
                    #print([TENGAHARVALSORT[i][0], TENGAHARVALSORT[i][1], TENGAHARVALSORT[j][0], TENGAHARVALSORT[j][1], TENGAHARVALSORT[k][0], TENGAHARVALSORT[k][1], TENGAHARVALSORT[l][0], TENGAHARVALSORT[l][1], TTENGAHVALUE, TTENGAHCOST])
                    DINAMIKTENGAH.append([TENGAHARVALSORT[i][0], TENGAHARVALSORT[i][1], TENGAHARVALSORT[j][0], TENGAHARVALSORT[j][1], TENGAHARVALSORT[k][0], TENGAHARVALSORT[k][1], TENGAHARVALSORT[l][0], TENGAHARVALSORT[l][1], TTENGAHVALUE, TTENGAHCOST])
        
#print(DINAMIKTENGAH)
#[Nama, Klub, Nama, Klub, Value, Cost]

DINAMIKTENGAHAR = np.array(DINAMIKTENGAH)
print(DINAMIKTENGAHAR)

#ASCENDING SORT
DINAMIKTENGAHARSORT=DINAMIKTENGAHAR[argsort(DINAMIKTENGAHAR[:, 4])]
print('Sorted Array : ')
print(DINAMIKTENGAHARSORT)

# %%
#ALGORITME MILIH 11 PEMAIN INTI
P1=KIPERARVALSORT[45][0] #KIPER
P2=BEKARVALSORT[162][0] #DEFENDER
P3=BEKARVALSORT[161][0] #DEFENDER
P4=BEKARVALSORT[160][0] #DEFENDER
P5=BEKARVALSORT[159][0] #DEFENDER
P6=TENGAHARVALSORT[195][0] #MIDFIELDER
P7=TENGAHARVALSORT[194][0] #MIDFIELDER
P8=TENGAHARVALSORT[193][0] #MIDFIELDER
P9=TENGAHARVALSORT[192][0] #MIDFIELDER
P10=DEPANARVALSORT[57][0] #FORWARD
P11=DEPANARVALSORT[56][0] #FORWARD
print('NAMA PEMAIN')
print('------', P10, '---', P11, '------')
print(P6, '---', P7, '---', P8, '---', P9)
print(P2, '---', P3, '---', P4, '---', P5)
print('------------', P1, '------------')

KLUBP1=KIPERARVALSORT[45][1] #KIPER
KLUBP2=BEKARVALSORT[162][1] #DEFENDER
KLUBP3=BEKARVALSORT[161][1] #DEFENDER
KLUBP4=BEKARVALSORT[160][1] #DEFENDER
KLUBP5=BEKARVALSORT[159][1] #DEFENDER
KLUBP6=TENGAHARVALSORT[195][1] #MIDFIELDER
KLUBP7=TENGAHARVALSORT[194][1] #MIDFIELDER
KLUBP8=TENGAHARVALSORT[193][1] #MIDFIELDER
KLUBP9=TENGAHARVALSORT[192][1] #MIDFIELDER
KLUBP10=DEPANARVALSORT[57][1] #FORWARD
KLUBP11=DEPANARVALSORT[56][1] #FORWARD
print('KLUB')
print('------', KLUBP10, '---', KLUBP11, '------')
print(KLUBP6, '---', KLUBP7, '---', KLUBP8, '---', KLUBP9)
print(KLUBP2, '---', KLUBP3, '---', KLUBP4, '---', KLUBP5)
print('------------', KLUBP1, '------------')

COSTP1=KIPERARVALSORT[45][3] #KIPER
COSTP2=BEKARVALSORT[162][3] #DEFENDER
COSTP3=BEKARVALSORT[161][3] #DEFENDER
COSTP4=BEKARVALSORT[160][3] #DEFENDER
COSTP5=BEKARVALSORT[159][3] #DEFENDER
COSTP6=TENGAHARVALSORT[195][3] #MIDFIELDER
COSTP7=TENGAHARVALSORT[194][3] #MIDFIELDER
COSTP8=TENGAHARVALSORT[193][3] #MIDFIELDER
COSTP9=TENGAHARVALSORT[192][3] #MIDFIELDER
COSTP10=DEPANARVALSORT[57][3] #FORWARD
COSTP11=DEPANARVALSORT[56][3] #FORWARD
print('HARGA')
print('------', COSTP10, '---', COSTP11, '------')
print(COSTP6, '---', COSTP7, '---', COSTP8, '---', COSTP9)
print(COSTP2, '---', COSTP3, '---', COSTP4, '---', COSTP5)
print('------------', COSTP1, '------------')

TOTAL=COSTP1+COSTP2+COSTP3+COSTP4+COSTP5+COSTP6+COSTP7+COSTP8+COSTP9+COSTP10+COSTP11
print('TOTAL HARGA')
print(TOTAL)


#MAKSIMAL COST 100-BEBAS (DIPILIH 100-17=83)
#URUTAN PEMILIHAN
#(BISA GAK YA MILIH SENDIRI URUTANNYA?)
#DEPAN
#TENGAH
#BELAKANG
#KIPER
#DEPAN
#TENGAH
#BELAKANG
#TENGAH
#BELAKANG
#TENGAH
#BELAKANG

#DEPAN MAX COST 
#TENGAH MAX COST 
#BELAKANG MAX COST 
#KIPER MAX COST
# Out:
# NAMA PEMAIN
# ------ Firmino --- Kane ------
# Fernandes --- Mount --- Rashford --- Son
# Robertson --- Alexander-Arnold --- Chilwell --- Azpilicueta
# ------------ Martínez ------------
# KLUB
# ------ Liverpool --- Spurs ------
# Man Utd --- Chelsea --- Man Utd --- Spurs
# Liverpool --- Liverpool --- Chelsea --- Chelsea
# ------------ Aston Villa ------------
# HARGA
# ------ 9.0 --- 12.5 ------
# 12.0 --- 7.5 --- 9.5 --- 10.0
# 7.0 --- 7.5 --- 6.0 --- 6.0
# ------------ 5.5 ------------
# TOTAL HARGA
# 92.5

# %%
#PROGRAM UNTUK NGULANGI LAGI KALO HARGANYA LEBIH DARI 100-BEBAS
#ALIAS -SAMA- BIAR NGGAK LEBIH DARI 100-BEBAS
#ALIAS ALGORITME PROGRAM DINAMIK

# %%
#PROGRAM UNTUK CANCEL PEMAIN KALO ADA YANG SATU KLUB LEBIH DARI 3 PEMAIN

# %%
#ALGORITME MILIH PEMAIN CADANGAN MASING2 POSISI SATU PEMAIN
#MAKSIMAL COST BEBAS (DIPILIH 17, BERDASARKAN COST TERENDAH TIAP POSISI)

# %%
#Pengatur Kasta Klub
BIG=['Arsenal', 'Chelsea', 'Liverpool', 'Man City', 'Man Utd', 'Spurs']
MEDIUM=['Aston Villa', 'Everton', 'Leeds', 'Leicester', 'Newcastle', 'Southampton', 'West Ham', 'Wolves']
SMALL=['Brentford', 'Brighton', 'Burnley', 'Crystal Palace', 'Norwich', 'Watford']
BIG2 = np.asarray(BIG)
MEDIUM2 = np.asarray(MEDIUM)
SMALL2 = np.asarray(SMALL)
print(BIG2)
print(MEDIUM2)
print(SMALL2)
# Out:
# ['Arsenal' 'Chelsea' 'Liverpool' 'Man City' 'Man Utd' 'Spurs']
# ['Aston Villa' 'Everton' 'Leeds' 'Leicester' 'Newcastle' 'Southampton'
#  'West Ham' 'Wolves']
# ['Brighton' 'Burnley' 'Crystal Palace' 'Fulham' 'Sheffield Utd'
#  'West Brom']

# %%
#Pengatur Peluang GW1
#PELUANG POIN GW1 (setelah 3 September)
GW1=[['Arsenal', 0.9], ['Aston Villa', 0.7], ['Brentford', 0.1], ['Brighton', 0.5], ['Burnley', 0.5], ['Chelsea', 0.9],
     ['Crystal Palace', 0.1], ['Everton', 0.5], ['Leeds', 0.3], ['Leicester', 0.5], ['Liverpool', 0.9], ['Man City', 0.5],
     ['Man Utd', 0.7], ['Newcastle', 0.5], ['Norwich', 0.1], ['Southampton', 0.5], ['Spurs', 0.5], ['Watford', 0.3],
     ['West Ham', 0.5], ['Wolves', 0.5]]
GW12 = np.asarray(GW1)
print(GW12)
# Out:
# [['Arsenal' '0.9']
#  ['Aston Villa' '0.3']
#  ['Brighton' '0.3']
#  ['Burnley' '0.3']
#  ['Chelsea' '0.9']
#  ['Crystal Palace' '0.1']
#  ['Everton' '0.7']
#  ['Fulham' '0.3']
#  ['Leeds' '0.3']
#  ['Leicester' '0.5']
#  ['Liverpool' '0.7']
#  ['Man City' '0.7']
#  ['Man Utd' '0.5']
#  ['Newcastle' '0.7']
#  ['Sheffield Utd' '0.1']
#  ['Southampton' '0.7']
#  ['Spurs' '0.5']
#  ['West Brom' '0.3']
#  ['West Ham' '0.5']
#  ['Wolves' '0.7']]
