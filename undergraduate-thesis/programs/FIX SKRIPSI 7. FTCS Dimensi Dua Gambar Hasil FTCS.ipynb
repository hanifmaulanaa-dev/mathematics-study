# %%
#PROGRAM UNTUK MENGELUARKAN HEATMAP HASIL
#METODE BEDA HINGGA EKSPLISIT DIMENSI DUA PADA PENGOLAHAN CITRA
#FORMASI SATU BARIS EMPAT CITRA
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(16,8))

plt.subplot(141)
pyplot.xticks([]), pyplot.yticks([1])
pyplot.imshow(W[0], cmap='gray')

plt.subplot(142)
pyplot.xticks([]), pyplot.yticks([])
pyplot.imshow(W[20], cmap='gray')

plt.subplot(143)
pyplot.xticks([]), pyplot.yticks([])
pyplot.imshow(W[50], cmap='gray')

plt.subplot(144)
pyplot.xticks([]), pyplot.yticks([])
pyplot.imshow(W[100], cmap='gray')

# %%
#PROGRAM UNTUK MENGELUARKAN HEATMAP HASIL
#METODE BEDA HINGGA EKSPLISIT DIMENSI DUA PADA PENGOLAHAN CITRA
#FORMASI DUA BARIS MASING-MASING DUA CITRA
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(16,8))

plt.subplot(221)
pyplot.xticks([]), pyplot.yticks([1])
pyplot.imshow(W[0], cmap='gray')

plt.subplot(222)
pyplot.xticks([]), pyplot.yticks([2])
pyplot.imshow(W[20], cmap='gray')

plt.subplot(223)
pyplot.xticks([]), pyplot.yticks([3])
pyplot.imshow(W[50], cmap='gray')

plt.subplot(224)
pyplot.xticks([]), pyplot.yticks([4])
pyplot.imshow(W[100], cmap='gray')
